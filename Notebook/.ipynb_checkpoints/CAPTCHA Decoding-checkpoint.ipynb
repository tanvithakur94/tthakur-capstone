# %% [markdown]
#                                                CAPTCHA IMAGE DECODER
# <img width = 300 height = 300 src="https://images.squarespace-cdn.com/content/v1/56eb3d2fe321407d6a06f3d5/1469233065334-SJNKAACBN328ZGI6WPMZ/Captcha.gif?format=2500w">

# %% [markdown]
# ### Importing Libraries

# %%
import os
import cv2
import pandas
import seaborn
import numpy as np
from PIL import Image
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
from keras.models import load_model
from keras.callbacks import ModelCheckpoint
from tensorflow.keras.utils import img_to_array
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.metrics import accuracy_score, classification_report
from keras.preprocessing.image import ImageDataGenerator

# for the CNN
from keras.models import Sequential 
from keras.layers import Dense
from keras.layers import Conv2D
from keras.layers import Flatten
from keras.layers import MaxPooling2D
from keras.layers import BatchNormalization
from keras.layers import Dropout
from keras.layers import Input

# %% [markdown]
# ### Getting our Data
# Chose a random image from the dataset and create a show_img function to load and show the image. Once the image is loaded, I converted it to grayscale using cv2.imread() and finally displayed the result.
# Grayscale means that the value of each pixel represents only the intensity information of the light. So, only black, white and gray colours will be present, hence just one layer image instead of RGB which has 3 different layers.
#
# Adaptive thresholding - It may not be good in all the conditions where image has different lighting conditions in different aread...so we go for adaptive thresholding. This algorithm calculates the threshold for a small regions of the image so we get different thresholds for different regions of the same image and it just gives better results for images with varying illumination. It has 3 different input parameters -
# Adaptive Method - It decides how thresholding value is calculated.
# cv2.ADAPTIVE_THRESH_MEAN_C : threshold value is the mean of neighbourhood area.
# cv2.ADAPTIVE_THRESH_GAUSSIAN_C : threshold value is the weighted sum of neighbourhood values where weights are a gaussian window.
# Block Size - It decides the size of neighbourhood area.
# C - It is just a constant which is subtracted from the mean or weighted mean calculated.

# %%
# setting the paths
path1 = '/Users/tthakur/Datasets/2cegf.png'
path2 = '/Users/tthakur/Datasets/23mdg.png'

# %%
# function to load and show the image
def show_img(img) :
    plt.figure(figsize = (6,3))   #height 3 and width 6 inches
    plt.imshow(img, 'gray')
    plt.axis('off')

# %%
# loading the image in grayscale
img1 = cv2.imread(path1, cv2.IMREAD_GRAYSCALE)
img2 = cv2.imread(path2, cv2.IMREAD_GRAYSCALE)

# %%
# calling function to show the images
show_img(img1)
show_img(img2)

# %% [markdown]
# ### Image Preprocesing

# %%
# adaptive thresholding: To change lighting conditions and obtain an abstract image 
thresh_img1 = cv2.adaptiveThreshold(img1, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 145, 0)
thresh_img2 = cv2.adaptiveThreshold(img2, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 145, 0)

show_img(thresh_img1)
show_img(thresh_img2)

# %%
#USING ADAPTIVE_THRESH_MEAN_C (MY)
#thresh_img1 = cv2.adaptiveThreshold(img1, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, 11, 2)
#show_img(thresh_img1)
#tried bunch of experimental values shown below.
#ret,th1 = cv2.threshold(img1,127,255,cv2.THRESH_BINARY)
#th2 = cv2.adaptiveThreshold(img1,255,cv2.ADAPTIVE_THRESH_MEAN_C,\
            #cv2.THRESH_BINARY,11,2)
#th3 = cv2.adaptiveThreshold(img1,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,\
            #cv2.THRESH_BINARY,11,2)
#show_img(th1)
#show_img(th2)
#show_img(th3)

# %% [markdown]
# ### Dilation
# So if you have an image in which you want to remove the noise, you can first apply erosion operation followed by dilation because erosion removes white noises, but it also shrinks our object; that is why we operate dilation, thereby preserving the original image. It is also useful in joining broken parts of the object.
# Generally, erosion is done before the dilation des away the boundaries of the foreground object
#
# Taking a matrix of size 2 as the kernel with which the image is convolved. dtype is uint8 for 8-bit images (0-255)

# %%
#img_erosion = cv2.erode(thresh_img1, np.ones((2,2), np.uint8, iterations=1)
#img_erosion = cv2.dilate(img_erosion, np.ones((2,2), np.uint8, iterations=1)
dil_img1 = cv2.dilate(thresh_img1, np.ones((2,2), np.uint8), iterations=1)
dil_img2 = cv2.dilate(thresh_img2, np.ones((2,2), np.uint8), iterations=1)

show_img(dil_img1)
show_img(dil_img2)

# %% [markdown]
# ### Segmenting the Image
#
# cv2.rectangle(image,start_point=(x,y),end_point=(x+w,y+h),color=(255,0,0),thickness=1,2)
# image: It is the image on which rectangle is to be drawn.
# start_point: It is the starting coordinates of rectangle. The coordinates are represented as tuples of two values i.e (X coordinate value, Y coordinate value)
# end_point: It is the ending coordinates of rectangle. The coordinates are represented as tuples of two values i.e. (X coordinate value, Y coordinate value)
# color: It is the color of border line of rectangle to be drawn. For BGR, we pass a tuple. eg: (255, 0, 0) for blue color.
# thickness: It is the thickness of the rectangle border line in px. Thickness of -1 px will fill the rectangle shape by the specified color.

# %%
cv2.rectangle(dil_img1, (30,12), (50,49), 0, 1)
cv2.rectangle(dil_img1, (50,12), (70,49), 0, 1)
cv2.rectangle(dil_img1, (70,12), (90,49), 0, 1)
cv2.rectangle(dil_img1, (90,12), (110,49),0, 1)
cv2.rectangle(dil_img1, (110,12),(130,49),0, 1)

cv2.rectangle(dil_img2, (30,12), (50,49), 0, 1)
cv2.rectangle(dil_img2, (50,12), (70,49), 0, 1)
cv2.rectangle(dil_img2, (70,12), (90,49), 0, 1)
cv2.rectangle(dil_img2, (90,12), (110,49),0, 1)
cv2.rectangle(dil_img2, (110,12),(130,49),0, 1)
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
show_img(dil_img1)
show_img(dil_img2)

# %% [markdown]
# ### Converting Images to Appropriate Samples
#
# Keras uses the img_to_array() function to convert the PIL image into numpy. The API also provides the array_to_img() function, which can be used for converting an array of pixel data into a PIL image.

# %%
def at_img(img) :
    return cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 145, 0)

def dil_img(img) :
    return cv2.dilate(img, np.ones((2,2), np.uint8), iterations = 1)

# %%
# initializing the path to loop through all images
path = '/Users/tthakur/Downloads/Datasets/'

# %%
X = []  # for storing broken up image as a list
y = []  # for keeping track of labels

for image in os.listdir(path):  # for all images in the dataset

    img = cv2.imread(os.path.join(path, image), cv2.IMREAD_GRAYSCALE)# reading image in grayscale
    
    img = at_img(img)   # applying adaptive thresholding
    img = dil_img(img)  # diluting the image
    
    # segmenting the image
    image_list = [img[10:50, 30:50], img[10:50, 50:70], img[10:50, 70:90], img[10:50, 90:110], img[10:50, 110:130]]
    
    # analyzing results for 1 image
    for i in range(5) :
        X.append(img_to_array(Image.fromarray(image_list[i])))  # saving the image's segmented list 
        y.append(image[i])                                      # saving the label for each character
        
X = np.array(X)
y = np.array(y)

# %%
print(X.shape)    #1070samples*5divisions=5350
print(y.shape)
# Out:
# (5350, 40, 20, 1)
# (5350,)

# %% [markdown]
# ### Scaling
# The general range for pixel is 0 to 255.So just by dividing by 255,we convert it to range from 0 to 1. The shape and other properties remain the same.

# %%
# scaling X: 
X /= 255.0

# %%
# displaying a segmented image
plt.figure(figsize = (20,5))
for i in range(5) :
    plt.subplot(1,5,i+1)
    plt.imshow(X[i], 'gray')
    plt.title('Label is ' + str(y[i]))
plt.plot()
# Out:
# []

# %% [markdown]
# ### Visualizing Data

# %%
# checking frequency of occurance of different characters
temp = set(y)
for t in temp:
    print('Frequency of ' + t + ': ' + str(len(y[y == t])))
# Out:
# Frequency of x: 271
# Frequency of y: 240
# Frequency of 7: 262
# Frequency of d: 269
# Frequency of b: 247
# Frequency of 5: 288
# Frequency of 4: 289
# Frequency of f: 277
# Frequency of w: 244
# Frequency of g: 281
# Frequency of p: 259
# Frequency of c: 276
# Frequency of 8: 272
# Frequency of 3: 271
# Frequency of e: 245
# Frequency of m: 282
# Frequency of 2: 270
# Frequency of n: 540
# Frequency of 6: 267

# %%
#Dataframe - 2-dimensional labeled data structure with columns of Characters and Count??
temp_df = pandas.DataFrame({'Characters' : [t for t in temp], 'Count' : [len(y[y==t]) for t in temp]})

# %%
plt.figure(figsize = (20,7))
seaborn.barplot(x = 'Characters', y = 'Count', data = temp_df, palette = 'plasma')
plt.title('Label distribution in CAPTCHAS', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Label distribution in CAPTCHAS')

# %% [markdown]
# ### One hot Encoding
# A one hot encoding is a representation of categorical variables as binary vectors.
# We can use get_dummies in pandas or np.utils or use OneHotEncoder() function in keras.
# Used one hot encoding since this model has categorical variables where no such ordinal relationship exists. This is where the integer encoded variable is removed and a new binary variable is added for each unique integer value.
# Sparse matrix = False

# %%
#integer encode and then one hot encoding for those integer values
y_combine = LabelEncoder().fit_transform(y)  # encoding first
#y_one_hot = OneHotEncoder(sparse = False).fit_transform(y.reshape(len(y),1))
y_one_hot = OneHotEncoder(sparse = False).fit_transform(y_combine.reshape(len(y_combine),1)) #reshape to give a new shape to array without changing the data

# %%
# let's see how encoding looks for one of the characters
#character either alphabet/number, count is freq of each character in dataset and labels are names corresponding to an image section.
print('Character: ' + str(y[1]))
print('Label: ' + str(y_combine[1]))
print('Count: ' + str(len(y_combine[y_combine == y_combine[1]])))
# Out:
# Character: 5
# Label: 3
# Count: 288

# %%
# for mapping back
info = {y_combine[i] : y[i] for i in range(len(y))}
info
# Out:
# {15: 'p',
#  3: '5',
#  12: 'g',
#  13: 'm',
#  10: 'e',
#  5: '7',
#  0: '2',
#  8: 'c',
#  9: 'd',
#  14: 'n',
#  4: '6',
#  6: '8',
#  16: 'w',
#  11: 'f',
#  7: 'b',
#  18: 'y',
#  17: 'x',
#  2: '4',
#  1: '3'}

# %%
print(X.shape)
print(y_one_hot.shape)  # one hot encoded form
# Out:
# (5350, 40, 20, 1)
# (5350, 19)

# %% [markdown]
# ### Splitting Dataset for Training & Testing

# %%
# splitting in the ratio of 80:20
X_train, X_test, y_train, y_test = train_test_split(X, y_one_hot, test_size = 0.2, random_state = 0)

# %% [markdown]
# ### CNN Creation
# A convolution multiplies a matrix of pixels with a filter matrix or ‘kernel’ and sums up the multiplication values. Then the convolution slides over to the next pixel and repeats the same process until all the image pixels have been covered.
#
# I used sequential model.  add() function is used to add layers to the model. First layers is Conv2D layer. These are convolution layers that will deal with our input images, which are seen as 2-dimensional matrices. 128, 32 16 are the number of nodes in each layer. These are all calculated experimentally. Kernel size gives us the filter matrix of 3x3. Activation is the activation function for the layer. The activation function we will be using for our first 2 layers is the ReLU, or Rectified Linear Activation. This activation function has been proven to work well in neural networks.
# Downsamples the input along its spatial dimensions (height and width) by taking the maximum value over an input window (of size defined by pool_size) for each channel of the input.One of "valid" or "same" (case-insensitive). "valid" means no padding. "same" results in padding evenly to the left/right or up/down of the input such that output has the same height/width dimension as the input.

# %%
model = Sequential()

model.add(Conv2D(128, (3,3), padding = 'same', activation = 'relu')) #good to start with the smallest filter size first
model.add(BatchNormalization()) #to standardize the output of hidden layers
model.add(Dropout(0.2))
model.add(MaxPooling2D(pool_size = (2,2), padding = 'same'))
#model.add(Dropout(0.2))


model.add(Conv2D(32, (3,3), padding = 'same', activation = 'relu'))
model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(MaxPooling2D(pool_size = (2,2), padding = 'same'))
#model.add(Dropout(0.2))

model.add(Conv2D(16, (3,3), padding = 'same', activation = 'relu'))
model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(MaxPooling2D(pool_size = (2,2), padding = 'same'))
#model.add(Dropout(0.2))

model.add(Flatten())

model.add(Dense(32, activation = 'relu'))
model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(Dense(32, activation = 'relu'))
model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(Dense(19, activation = 'softmax'))
    
model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])
# Out:
# 2022-08-03 00:49:33.778637: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ### Image Data Generation

# %%
#shift the image along X-axis by 20% and Y-axis by 20%. rotation_range for rotating the image at an angle from 0 to 180 degrees.
traingen = ImageDataGenerator(rotation_range = 5, width_shift_range = [-2,2])
traingen.fit(X_train)

# %%
train_set = traingen.flow(X_train, y_train)

# %%
trainX, trainy = train_set.next()

# %%
# augmented images with rotations and shifts
plt.figure(figsize = (10,10))
hi = 32
lo = 0
for i in range(8) :
    plt.subplot(4,4,i+1)
    x = np.random.randint(lo, hi)
    plt.imshow(trainX[x], 'gray')
plt.show()

# %% [markdown]
# ### Setting up Model Checkpoint
#
# A good use of checkpointing is to output the model weights each time an improvement is observed during training. Setting save_best_only=True ensures that the latest best model (according to the metric monitored) will not be overwritten. Finally, the verbose=1 setting simply logs a notification to our terminal when a model is being serialized to disk during training. If we instead wanted to monitor the training loss and accuracy the variable would become train_loss and train_acc, respectively for "monitor" parameter.

# %%
checkp = ModelCheckpoint('./best_model.h5', monitor = 'val_loss', verbose = 1, save_best_only = True)

# %% [markdown]
# ### Fitting the Model
# This will make all invocations of tf.function run eagerly instead of running as a traced graph function.
#
# This can be useful for debugging.
# A number of epochs mean how many times you go through your training set. Lower no. of epochs to ensure less overfitting.
# Batch-size is the no. of training samples that will be viewed to ensure faster convergence.
#
# Larger the batch size...faster the trin time and better bias.

# %%
tf.config.run_functions_eagerly(True)  #mainly helpful for debugging

# %%
history = model.fit(traingen.flow(X_train, y_train, batch_size = 32), validation_data = (X_test, y_test), epochs = 150, 
                    steps_per_epoch = len(X_train)/32, callbacks = [checkp])
# Out:
# Epoch 1/150
# /opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/data/ops/structured_function.py:264: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   warnings.warn(
# 134/133 [==============================] - ETA: 0s - loss: 2.9295 - accuracy: 0.1425
# Epoch 1: val_loss improved from inf to 3.26247, saving model to ./best_model.h5
# 133/133 [==============================] - 17s 125ms/step - loss: 2.9295 - accuracy: 0.1425 - val_loss: 3.2625 - val_accuracy: 0.0514
# Epoch 2/150
# 134/133 [==============================] - ETA: 0s - loss: 2.0692 - accuracy: 0.3951
# Epoch 2: val_loss did not improve from 3.26247
# 133/133 [==============================] - 17s 124ms/step - loss: 2.0692 - accuracy: 0.3951 - val_loss: 3.5368 - val_accuracy: 0.1028
# Epoch 3/150
# 134/133 [==============================] - ETA: 0s - loss: 1.5925 - accuracy: 0.5453
# Epoch 3: val_loss did not improve from 3.26247
# 133/133 [==============================] - 17s 126ms/step - loss: 1.5925 - accuracy: 0.5453 - val_loss: 3.4250 - val_accuracy: 0.1879
# Epoch 4/150
# 134/133 [==============================] - ETA: 0s - loss: 1.3337 - accuracy: 0.6276
# Epoch 4: val_loss improved from 3.26247 to 1.46362, saving model to ./best_model.h5
# 133/133 [==============================] - 17s 127ms/step - loss: 1.3337 - accuracy: 0.6276 - val_loss: 1.4636 - val_accuracy: 0.6364
# Epoch 5/150
# 134/133 [==============================] - ETA: 0s - loss: 1.1416 - accuracy: 0.6881
# Epoch 5: val_loss improved from 1.46362 to 0.77014, saving model to ./best_model.h5
# 133/133 [==============================] - 17s 125ms/step - loss: 1.1416 - accuracy: 0.6881 - val_loss: 0.7701 - val_accuracy: 0.8196
# Epoch 6/150
# 134/133 [==============================] - ETA: 0s - loss: 0.9980 - accuracy: 0.7231
# Epoch 6: val_loss did not improve from 0.77014
# 133/133 [==============================] - 18s 132ms/step - loss: 0.9980 - accuracy: 0.7231 - val_loss: 0.8493 - val_accuracy: 0.7598
# Epoch 7/150
# 134/133 [==============================] - ETA: 0s - loss: 0.9375 - accuracy: 0.7430
# Epoch 7: val_loss improved from 0.77014 to 0.59727, saving model to ./best_model.h5
# 133/133 [==============================] - 18s 132ms/step - loss: 0.9375 - accuracy: 0.7430 - val_loss: 0.5973 - val_accuracy: 0.8402
# Epoch 8/150
# 134/133 [==============================] - ETA: 0s - loss: 0.8361 - accuracy: 0.7736
# Epoch 8: val_loss improved from 0.59727 to 0.52783, saving model to ./best_model.h5
# 133/133 [==============================] - 17s 127ms/step - loss: 0.8361 - accuracy: 0.7736 - val_loss: 0.5278 - val_accuracy: 0.8533
# Epoch 9/150
# 134/133 [==============================] - ETA: 0s - loss: 0.8150 - accuracy: 0.7792
# Epoch 9: val_loss improved from 0.52783 to 0.52667, saving model to ./best_model.h5
# 133/133 [==============================] - 17s 126ms/step - loss: 0.8150 - accuracy: 0.7792 - val_loss: 0.5267 - val_accuracy: 0.8495
# Epoch 10/150
# 134/133 [==============================] - ETA: 0s - loss: 0.7657 - accuracy: 0.7902
# Epoch 10: val_loss did not improve from 0.52667
# 133/133 [==============================] - 17s 125ms/step - loss: 0.7657 - accuracy: 0.7902 - val_loss: 0.5597 - val_accuracy: 0.8121
# Epoch 11/150
# 134/133 [==============================] - ETA: 0s - loss: 0.7053 - accuracy: 0.8028
# Epoch 11: val_loss improved from 0.52667 to 0.48353, saving model to ./best_model.h5
# 133/133 [==============================] - 17s 125ms/step - loss: 0.7053 - accuracy: 0.8028 - val_loss: 0.4835 - val_accuracy: 0.8607
# Epoch 12/150
# 134/133 [==============================] - ETA: 0s - loss: 0.6707 - accuracy: 0.8152
# Epoch 12: val_loss improved from 0.48353 to 0.46259, saving model to ./best_model.h5
# 133/133 [==============================] - 17s 127ms/step - loss: 0.6707 - accuracy: 0.8152 - val_loss: 0.4626 - val_accuracy: 0.8710
# Epoch 13/150
# 134/133 [==============================] - ETA: 0s - loss: 0.6557 - accuracy: 0.8152
# Epoch 13: val_loss did not improve from 0.46259
# 133/133 [==============================] - 16s 122ms/step - loss: 0.6557 - accuracy: 0.8152 - val_loss: 0.4641 - val_accuracy: 0.8692
# Epoch 14/150
# 134/133 [==============================] - ETA: -13s - loss: 0.6419 - accuracy: 0.8217
# Epoch 14: val_loss improved from 0.46259 to 0.43999, saving model to ./best_model.h5
# 133/133 [==============================] - 7213s 54s/step - loss: 0.6419 - accuracy: 0.8217 - val_loss: 0.4400 - val_accuracy: 0.8757
# Epoch 15/150
# 134/133 [==============================] - ETA: 0s - loss: 0.6423 - accuracy: 0.8166
# Epoch 15: val_loss did not improve from 0.43999
# 133/133 [==============================] - 404s 3s/step - loss: 0.6423 - accuracy: 0.8166 - val_loss: 0.4610 - val_accuracy: 0.8673
# Epoch 16/150
# 134/133 [==============================] - ETA: 0s - loss: 0.5812 - accuracy: 0.8376
# Epoch 16: val_loss improved from 0.43999 to 0.42778, saving model to ./best_model.h5
# 133/133 [==============================] - 17s 125ms/step - loss: 0.5812 - accuracy: 0.8376 - val_loss: 0.4278 - val_accuracy: 0.8701
# Epoch 17/150
# 134/133 [==============================] - ETA: -13s - loss: 0.5736 - accuracy: 0.8383
# Epoch 17: val_loss improved from 0.42778 to 0.37334, saving model to ./best_model.h5
# 133/133 [==============================] - 7218s 54s/step - loss: 0.5736 - accuracy: 0.8383 - val_loss: 0.3733 - val_accuracy: 0.8916
# Epoch 18/150
# 134/133 [==============================] - ETA: -4s - loss: 0.5710 - accuracy: 0.8397
# Epoch 18: val_loss did not improve from 0.37334
# 133/133 [==============================] - 9857s 20s/step - loss: 0.5710 - accuracy: 0.8397 - val_loss: 0.4476 - val_accuracy: 0.8654
# Epoch 19/150
# 134/133 [==============================] - ETA: 0s - loss: 0.5494 - accuracy: 0.8348
# Epoch 19: val_loss did not improve from 0.37334
# 133/133 [==============================] - 17s 126ms/step - loss: 0.5494 - accuracy: 0.8348 - val_loss: 0.3946 - val_accuracy: 0.8944
# Epoch 20/150
# 134/133 [==============================] - ETA: -4s - loss: 0.5511 - accuracy: 0.8481
# Epoch 20: val_loss did not improve from 0.37334
# 133/133 [==============================] - 2450s 18s/step - loss: 0.5511 - accuracy: 0.8481 - val_loss: 0.4047 - val_accuracy: 0.8841
# Epoch 21/150
# 134/133 [==============================] - ETA: 0s - loss: 0.5321 - accuracy: 0.8491
# Epoch 21: val_loss did not improve from 0.37334
# 133/133 [==============================] - 21s 154ms/step - loss: 0.5321 - accuracy: 0.8491 - val_loss: 0.4493 - val_accuracy: 0.8710
# Epoch 22/150
# 134/133 [==============================] - ETA: 0s - loss: 0.5204 - accuracy: 0.8561
# Epoch 22: val_loss did not improve from 0.37334
# 133/133 [==============================] - 17s 128ms/step - loss: 0.5204 - accuracy: 0.8561 - val_loss: 0.3883 - val_accuracy: 0.8879
# Epoch 23/150
# 134/133 [==============================] - ETA: 0s - loss: 0.5338 - accuracy: 0.8521
# Epoch 23: val_loss did not improve from 0.37334
# 133/133 [==============================] - 16s 122ms/step - loss: 0.5338 - accuracy: 0.8521 - val_loss: 0.3744 - val_accuracy: 0.8963
# Epoch 24/150
# 134/133 [==============================] - ETA: 0s - loss: 0.5049 - accuracy: 0.8551
# Epoch 24: val_loss did not improve from 0.37334
# 133/133 [==============================] - 16s 123ms/step - loss: 0.5049 - accuracy: 0.8551 - val_loss: 0.3978 - val_accuracy: 0.8766
# Epoch 25/150
# 134/133 [==============================] - ETA: 0s - loss: 0.4903 - accuracy: 0.8593
# Epoch 25: val_loss did not improve from 0.37334
# 133/133 [==============================] - 16s 123ms/step - loss: 0.4903 - accuracy: 0.8593 - val_loss: 0.3932 - val_accuracy: 0.8907
# Epoch 26/150
# 134/133 [==============================] - ETA: 0s - loss: 0.5010 - accuracy: 0.8565
# Epoch 26: val_loss improved from 0.37334 to 0.36178, saving model to ./best_model.h5
# 133/133 [==============================] - 16s 121ms/step - loss: 0.5010 - accuracy: 0.8565 - val_loss: 0.3618 - val_accuracy: 0.9056
# Epoch 27/150
# 134/133 [==============================] - ETA: 0s - loss: 0.4835 - accuracy: 0.8617
# Epoch 27: val_loss improved from 0.36178 to 0.34508, saving model to ./best_model.h5
# 133/133 [==============================] - 122s 917ms/step - loss: 0.4835 - accuracy: 0.8617 - val_loss: 0.3451 - val_accuracy: 0.9084
# Epoch 28/150
# 134/133 [==============================] - ETA: 0s - loss: 0.4844 - accuracy: 0.8607
# Epoch 28: val_loss did not improve from 0.34508
# 133/133 [==============================] - 17s 124ms/step - loss: 0.4844 - accuracy: 0.8607 - val_loss: 0.3586 - val_accuracy: 0.9037
# Epoch 29/150
# 134/133 [==============================] - ETA: 0s - loss: 0.4702 - accuracy: 0.8673
# Epoch 29: val_loss did not improve from 0.34508
# 133/133 [==============================] - 17s 126ms/step - loss: 0.4702 - accuracy: 0.8673 - val_loss: 0.5012 - val_accuracy: 0.8178
# Epoch 30/150
# 134/133 [==============================] - ETA: 0s - loss: 0.4739 - accuracy: 0.8661
# Epoch 30: val_loss did not improve from 0.34508
# 133/133 [==============================] - 16s 123ms/step - loss: 0.4739 - accuracy: 0.8661 - val_loss: 0.3974 - val_accuracy: 0.8850
# Epoch 31/150
# 134/133 [==============================] - ETA: 0s - loss: 0.4556 - accuracy: 0.8685
# Epoch 31: val_loss did not improve from 0.34508
# 133/133 [==============================] - 17s 124ms/step - loss: 0.4556 - accuracy: 0.8685 - val_loss: 0.3966 - val_accuracy: 0.8869
# Epoch 32/150
# 134/133 [==============================] - ETA: 0s - loss: 0.4650 - accuracy: 0.8694
# Epoch 32: val_loss did not improve from 0.34508
# 133/133 [==============================] - 16s 121ms/step - loss: 0.4650 - accuracy: 0.8694 - val_loss: 0.3467 - val_accuracy: 0.9065
# Epoch 33/150
# 134/133 [==============================] - ETA: 0s - loss: 0.4465 - accuracy: 0.8715
# Epoch 33: val_loss did not improve from 0.34508
# 133/133 [==============================] - 17s 125ms/step - loss: 0.4465 - accuracy: 0.8715 - val_loss: 0.4006 - val_accuracy: 0.8710
# Epoch 34/150
# 134/133 [==============================] - ETA: 0s - loss: 0.4417 - accuracy: 0.8769
# Epoch 34: val_loss did not improve from 0.34508
# 133/133 [==============================] - 509s 4s/step - loss: 0.4417 - accuracy: 0.8769 - val_loss: 0.3590 - val_accuracy: 0.8981
# Epoch 35/150
# 134/133 [==============================] - ETA: 0s - loss: 0.4551 - accuracy: 0.8689
# Epoch 35: val_loss did not improve from 0.34508
# 133/133 [==============================] - 19s 141ms/step - loss: 0.4551 - accuracy: 0.8689 - val_loss: 0.3965 - val_accuracy: 0.8832
# Epoch 36/150
# 134/133 [==============================] - ETA: 0s - loss: 0.4708 - accuracy: 0.8640
# Epoch 36: val_loss did not improve from 0.34508
# 133/133 [==============================] - 18s 138ms/step - loss: 0.4708 - accuracy: 0.8640 - val_loss: 0.4011 - val_accuracy: 0.8832
# Epoch 37/150
# 134/133 [==============================] - ETA: 0s - loss: 0.4317 - accuracy: 0.8736
# Epoch 37: val_loss did not improve from 0.34508
# 133/133 [==============================] - 18s 132ms/step - loss: 0.4317 - accuracy: 0.8736 - val_loss: 0.3514 - val_accuracy: 0.8935
# Epoch 38/150
# 134/133 [==============================] - ETA: 0s - loss: 0.3924 - accuracy: 0.8900
# Epoch 38: val_loss did not improve from 0.34508
# 133/133 [==============================] - 17s 131ms/step - loss: 0.3924 - accuracy: 0.8900 - val_loss: 0.3593 - val_accuracy: 0.8879
# Epoch 39/150
# 134/133 [==============================] - ETA: 0s - loss: 0.4387 - accuracy: 0.8731
# Epoch 39: val_loss improved from 0.34508 to 0.33808, saving model to ./best_model.h5
# 133/133 [==============================] - 17s 125ms/step - loss: 0.4387 - accuracy: 0.8731 - val_loss: 0.3381 - val_accuracy: 0.9140
# Epoch 40/150
# 134/133 [==============================] - ETA: 0s - loss: 0.4201 - accuracy: 0.8787
# Epoch 40: val_loss improved from 0.33808 to 0.33266, saving model to ./best_model.h5
# 133/133 [==============================] - 17s 126ms/step - loss: 0.4201 - accuracy: 0.8787 - val_loss: 0.3327 - val_accuracy: 0.9075
# Epoch 41/150
# 134/133 [==============================] - ETA: 0s - loss: 0.3981 - accuracy: 0.8857
# Epoch 41: val_loss did not improve from 0.33266
# 133/133 [==============================] - 17s 125ms/step - loss: 0.3981 - accuracy: 0.8857 - val_loss: 0.3436 - val_accuracy: 0.9103
# Epoch 42/150
# 134/133 [==============================] - ETA: 0s - loss: 0.4299 - accuracy: 0.8764
# Epoch 42: val_loss did not improve from 0.33266
# 133/133 [==============================] - 17s 127ms/step - loss: 0.4299 - accuracy: 0.8764 - val_loss: 0.3664 - val_accuracy: 0.9019
# Epoch 43/150
# 134/133 [==============================] - ETA: 0s - loss: 0.4038 - accuracy: 0.8871
# Epoch 43: val_loss did not improve from 0.33266
# 133/133 [==============================] - 17s 129ms/step - loss: 0.4038 - accuracy: 0.8871 - val_loss: 0.3331 - val_accuracy: 0.9150
# Epoch 44/150
# 134/133 [==============================] - ETA: 0s - loss: 0.4101 - accuracy: 0.8850
# Epoch 44: val_loss did not improve from 0.33266
# 133/133 [==============================] - 17s 126ms/step - loss: 0.4101 - accuracy: 0.8850 - val_loss: 0.3469 - val_accuracy: 0.9037
# Epoch 45/150
# 134/133 [==============================] - ETA: 0s - loss: 0.3964 - accuracy: 0.8848
# Epoch 45: val_loss did not improve from 0.33266
# 133/133 [==============================] - 17s 124ms/step - loss: 0.3964 - accuracy: 0.8848 - val_loss: 0.3470 - val_accuracy: 0.9075
# Epoch 46/150
# 134/133 [==============================] - ETA: 0s - loss: 0.4047 - accuracy: 0.8848
# Epoch 46: val_loss did not improve from 0.33266
# 133/133 [==============================] - 17s 126ms/step - loss: 0.4047 - accuracy: 0.8848 - val_loss: 0.3535 - val_accuracy: 0.8907
# Epoch 47/150
# 134/133 [==============================] - ETA: 0s - loss: 0.3993 - accuracy: 0.8864
# Epoch 47: val_loss did not improve from 0.33266
# 133/133 [==============================] - 17s 126ms/step - loss: 0.3993 - accuracy: 0.8864 - val_loss: 0.3609 - val_accuracy: 0.9000
# Epoch 48/150
# 134/133 [==============================] - ETA: 0s - loss: 0.3976 - accuracy: 0.8883
# Epoch 48: val_loss did not improve from 0.33266
# 133/133 [==============================] - 17s 124ms/step - loss: 0.3976 - accuracy: 0.8883 - val_loss: 0.3392 - val_accuracy: 0.9028
# Epoch 49/150
# 134/133 [==============================] - ETA: 0s - loss: 0.3805 - accuracy: 0.8883
# Epoch 49: val_loss did not improve from 0.33266
# 133/133 [==============================] - 17s 125ms/step - loss: 0.3805 - accuracy: 0.8883 - val_loss: 0.4038 - val_accuracy: 0.8785
# Epoch 50/150
# 134/133 [==============================] - ETA: 0s - loss: 0.3825 - accuracy: 0.8916
# Epoch 50: val_loss did not improve from 0.33266
# 133/133 [==============================] - 17s 126ms/step - loss: 0.3825 - accuracy: 0.8916 - val_loss: 0.3488 - val_accuracy: 0.9150
# Epoch 51/150
# 134/133 [==============================] - ETA: 0s - loss: 0.3722 - accuracy: 0.8902
# Epoch 51: val_loss did not improve from 0.33266
# 133/133 [==============================] - 17s 125ms/step - loss: 0.3722 - accuracy: 0.8902 - val_loss: 0.3630 - val_accuracy: 0.8953
# Epoch 52/150
# 134/133 [==============================] - ETA: 0s - loss: 0.3925 - accuracy: 0.8860
# Epoch 52: val_loss did not improve from 0.33266
# 133/133 [==============================] - 16s 120ms/step - loss: 0.3925 - accuracy: 0.8860 - val_loss: 0.3570 - val_accuracy: 0.8925
# Epoch 53/150
# 134/133 [==============================] - ETA: 0s - loss: 0.3890 - accuracy: 0.8897
# Epoch 53: val_loss did not improve from 0.33266
# 133/133 [==============================] - 17s 124ms/step - loss: 0.3890 - accuracy: 0.8897 - val_loss: 0.3354 - val_accuracy: 0.9093
# Epoch 54/150
# 134/133 [==============================] - ETA: 0s - loss: 0.3725 - accuracy: 0.8921
# Epoch 54: val_loss did not improve from 0.33266
# 133/133 [==============================] - 17s 125ms/step - loss: 0.3725 - accuracy: 0.8921 - val_loss: 0.3566 - val_accuracy: 0.8897
# Epoch 55/150
# 134/133 [==============================] - ETA: 0s - loss: 0.3706 - accuracy: 0.8862
# Epoch 55: val_loss did not improve from 0.33266
# 133/133 [==============================] - 17s 126ms/step - loss: 0.3706 - accuracy: 0.8862 - val_loss: 0.3578 - val_accuracy: 0.8925
# Epoch 56/150
# 134/133 [==============================] - ETA: 0s - loss: 0.3759 - accuracy: 0.8886
# Epoch 56: val_loss did not improve from 0.33266
# 133/133 [==============================] - 17s 126ms/step - loss: 0.3759 - accuracy: 0.8886 - val_loss: 0.3519 - val_accuracy: 0.8981
# Epoch 57/150
# 134/133 [==============================] - ETA: 0s - loss: 0.3659 - accuracy: 0.8979
# Epoch 57: val_loss did not improve from 0.33266
# 133/133 [==============================] - 17s 125ms/step - loss: 0.3659 - accuracy: 0.8979 - val_loss: 0.3430 - val_accuracy: 0.8991
# Epoch 58/150
# 134/133 [==============================] - ETA: 0s - loss: 0.3661 - accuracy: 0.8902
# Epoch 58: val_loss did not improve from 0.33266
# 133/133 [==============================] - 17s 126ms/step - loss: 0.3661 - accuracy: 0.8902 - val_loss: 0.3353 - val_accuracy: 0.9150
# Epoch 59/150
# 134/133 [==============================] - ETA: 0s - loss: 0.3651 - accuracy: 0.8869
# Epoch 59: val_loss did not improve from 0.33266
# 133/133 [==============================] - 17s 126ms/step - loss: 0.3651 - accuracy: 0.8869 - val_loss: 0.3354 - val_accuracy: 0.9065
# Epoch 60/150
# 134/133 [==============================] - ETA: 0s - loss: 0.3724 - accuracy: 0.8893
# Epoch 60: val_loss did not improve from 0.33266
# 133/133 [==============================] - 17s 125ms/step - loss: 0.3724 - accuracy: 0.8893 - val_loss: 0.3336 - val_accuracy: 0.9121
# Epoch 61/150
# 134/133 [==============================] - ETA: 0s - loss: 0.3551 - accuracy: 0.8921
# Epoch 61: val_loss improved from 0.33266 to 0.33169, saving model to ./best_model.h5
# 133/133 [==============================] - 17s 126ms/step - loss: 0.3551 - accuracy: 0.8921 - val_loss: 0.3317 - val_accuracy: 0.9028
# Epoch 62/150
# 134/133 [==============================] - ETA: 0s - loss: 0.3539 - accuracy: 0.8974
# Epoch 62: val_loss did not improve from 0.33169
# 133/133 [==============================] - 17s 125ms/step - loss: 0.3539 - accuracy: 0.8974 - val_loss: 0.3569 - val_accuracy: 0.9075
# Epoch 63/150
# 134/133 [==============================] - ETA: 0s - loss: 0.3607 - accuracy: 0.8907
# Epoch 63: val_loss did not improve from 0.33169
# 133/133 [==============================] - 17s 125ms/step - loss: 0.3607 - accuracy: 0.8907 - val_loss: 0.3404 - val_accuracy: 0.9131
# Epoch 64/150
# 134/133 [==============================] - ETA: 0s - loss: 0.3475 - accuracy: 0.8979
# Epoch 64: val_loss did not improve from 0.33169
# 133/133 [==============================] - 17s 125ms/step - loss: 0.3475 - accuracy: 0.8979 - val_loss: 0.3562 - val_accuracy: 0.9009
# Epoch 65/150
# 134/133 [==============================] - ETA: 0s - loss: 0.3446 - accuracy: 0.8939
# Epoch 65: val_loss did not improve from 0.33169
# 133/133 [==============================] - 17s 125ms/step - loss: 0.3446 - accuracy: 0.8939 - val_loss: 0.3431 - val_accuracy: 0.9047
# Epoch 66/150
# 134/133 [==============================] - ETA: 0s - loss: 0.3430 - accuracy: 0.9005
# Epoch 66: val_loss improved from 0.33169 to 0.32108, saving model to ./best_model.h5
# 133/133 [==============================] - 17s 126ms/step - loss: 0.3430 - accuracy: 0.9005 - val_loss: 0.3211 - val_accuracy: 0.9168
# Epoch 67/150
# 134/133 [==============================] - ETA: 0s - loss: 0.3485 - accuracy: 0.8984
# Epoch 67: val_loss did not improve from 0.32108
# 133/133 [==============================] - 17s 126ms/step - loss: 0.3485 - accuracy: 0.8984 - val_loss: 0.3743 - val_accuracy: 0.8897
# Epoch 68/150
# 134/133 [==============================] - ETA: 0s - loss: 0.3369 - accuracy: 0.8960
# Epoch 68: val_loss did not improve from 0.32108
# 133/133 [==============================] - 17s 125ms/step - loss: 0.3369 - accuracy: 0.8960 - val_loss: 0.3425 - val_accuracy: 0.9112
# Epoch 69/150
# 134/133 [==============================] - ETA: 0s - loss: 0.3358 - accuracy: 0.9016
# Epoch 69: val_loss did not improve from 0.32108
# 133/133 [==============================] - 17s 125ms/step - loss: 0.3358 - accuracy: 0.9016 - val_loss: 0.3307 - val_accuracy: 0.9056
# Epoch 70/150
# 134/133 [==============================] - ETA: 0s - loss: 0.3213 - accuracy: 0.9047
# Epoch 70: val_loss did not improve from 0.32108
# 133/133 [==============================] - 17s 127ms/step - loss: 0.3213 - accuracy: 0.9047 - val_loss: 0.3414 - val_accuracy: 0.9168
# Epoch 71/150
# 134/133 [==============================] - ETA: 0s - loss: 0.3366 - accuracy: 0.8995
# Epoch 71: val_loss did not improve from 0.32108
# 133/133 [==============================] - 17s 126ms/step - loss: 0.3366 - accuracy: 0.8995 - val_loss: 0.3676 - val_accuracy: 0.8991
# Epoch 72/150
# 134/133 [==============================] - ETA: 0s - loss: 0.3752 - accuracy: 0.8911
# Epoch 72: val_loss did not improve from 0.32108
# 133/133 [==============================] - 17s 125ms/step - loss: 0.3752 - accuracy: 0.8911 - val_loss: 0.3403 - val_accuracy: 0.9093
# Epoch 73/150
# 134/133 [==============================] - ETA: 0s - loss: 0.3288 - accuracy: 0.8979
# Epoch 73: val_loss did not improve from 0.32108
# 133/133 [==============================] - 17s 126ms/step - loss: 0.3288 - accuracy: 0.8979 - val_loss: 0.3347 - val_accuracy: 0.9075
# Epoch 74/150
# 134/133 [==============================] - ETA: 0s - loss: 0.3461 - accuracy: 0.9019
# Epoch 74: val_loss did not improve from 0.32108
# 133/133 [==============================] - 17s 125ms/step - loss: 0.3461 - accuracy: 0.9019 - val_loss: 0.3291 - val_accuracy: 0.9224
# Epoch 75/150
# 134/133 [==============================] - ETA: 0s - loss: 0.3252 - accuracy: 0.9009
# Epoch 75: val_loss did not improve from 0.32108
# 133/133 [==============================] - 16s 123ms/step - loss: 0.3252 - accuracy: 0.9009 - val_loss: 0.3464 - val_accuracy: 0.9019
# Epoch 76/150
# 134/133 [==============================] - ETA: 0s - loss: 0.3336 - accuracy: 0.8988
# Epoch 76: val_loss improved from 0.32108 to 0.32012, saving model to ./best_model.h5
# 133/133 [==============================] - 17s 126ms/step - loss: 0.3336 - accuracy: 0.8988 - val_loss: 0.3201 - val_accuracy: 0.9196
# Epoch 77/150
# 134/133 [==============================] - ETA: 0s - loss: 0.3287 - accuracy: 0.9042
# Epoch 77: val_loss did not improve from 0.32012
# 133/133 [==============================] - 17s 125ms/step - loss: 0.3287 - accuracy: 0.9042 - val_loss: 0.3468 - val_accuracy: 0.8963
# Epoch 78/150
# 134/133 [==============================] - ETA: 0s - loss: 0.3239 - accuracy: 0.9049
# Epoch 78: val_loss did not improve from 0.32012
# 133/133 [==============================] - 17s 126ms/step - loss: 0.3239 - accuracy: 0.9049 - val_loss: 0.3507 - val_accuracy: 0.8935
# Epoch 79/150
# 134/133 [==============================] - ETA: 0s - loss: 0.3190 - accuracy: 0.9026
# Epoch 79: val_loss did not improve from 0.32012
# 133/133 [==============================] - 17s 126ms/step - loss: 0.3190 - accuracy: 0.9026 - val_loss: 0.3340 - val_accuracy: 0.9112
# Epoch 80/150
# 134/133 [==============================] - ETA: 0s - loss: 0.3284 - accuracy: 0.8949
# Epoch 80: val_loss did not improve from 0.32012
# 133/133 [==============================] - 17s 126ms/step - loss: 0.3284 - accuracy: 0.8949 - val_loss: 0.3315 - val_accuracy: 0.9103
# Epoch 81/150
# 134/133 [==============================] - ETA: 0s - loss: 0.3288 - accuracy: 0.9023
# Epoch 81: val_loss did not improve from 0.32012
# 133/133 [==============================] - 17s 126ms/step - loss: 0.3288 - accuracy: 0.9023 - val_loss: 0.3632 - val_accuracy: 0.9009
# Epoch 82/150
# 134/133 [==============================] - ETA: 0s - loss: 0.3230 - accuracy: 0.8949
# Epoch 82: val_loss did not improve from 0.32012
# 133/133 [==============================] - 17s 125ms/step - loss: 0.3230 - accuracy: 0.8949 - val_loss: 0.3321 - val_accuracy: 0.9037
# Epoch 83/150
# 134/133 [==============================] - ETA: 0s - loss: 0.3339 - accuracy: 0.8972
# Epoch 83: val_loss did not improve from 0.32012
# 133/133 [==============================] - 17s 127ms/step - loss: 0.3339 - accuracy: 0.8972 - val_loss: 0.3332 - val_accuracy: 0.9093
# Epoch 84/150
# 134/133 [==============================] - ETA: 0s - loss: 0.3275 - accuracy: 0.8965
# Epoch 84: val_loss did not improve from 0.32012
# 133/133 [==============================] - 17s 126ms/step - loss: 0.3275 - accuracy: 0.8965 - val_loss: 0.3305 - val_accuracy: 0.9121
# Epoch 85/150
# 134/133 [==============================] - ETA: 0s - loss: 0.2959 - accuracy: 0.9082
# Epoch 85: val_loss did not improve from 0.32012
# 133/133 [==============================] - 17s 126ms/step - loss: 0.2959 - accuracy: 0.9082 - val_loss: 0.3627 - val_accuracy: 0.9121
# Epoch 86/150
# 134/133 [==============================] - ETA: 0s - loss: 0.3162 - accuracy: 0.9047
# Epoch 86: val_loss did not improve from 0.32012
# 133/133 [==============================] - 17s 126ms/step - loss: 0.3162 - accuracy: 0.9047 - val_loss: 0.3322 - val_accuracy: 0.9084
# Epoch 87/150
# 134/133 [==============================] - ETA: 0s - loss: 0.3101 - accuracy: 0.9047
# Epoch 87: val_loss did not improve from 0.32012
# 133/133 [==============================] - 17s 125ms/step - loss: 0.3101 - accuracy: 0.9047 - val_loss: 0.3291 - val_accuracy: 0.9121
# Epoch 88/150
# 134/133 [==============================] - ETA: 0s - loss: 0.3164 - accuracy: 0.9014
# Epoch 88: val_loss did not improve from 0.32012
# 133/133 [==============================] - 17s 126ms/step - loss: 0.3164 - accuracy: 0.9014 - val_loss: 0.3340 - val_accuracy: 0.9187
# Epoch 89/150
# 134/133 [==============================] - ETA: 0s - loss: 0.2956 - accuracy: 0.9098
# Epoch 89: val_loss did not improve from 0.32012
# 133/133 [==============================] - 17s 126ms/step - loss: 0.2956 - accuracy: 0.9098 - val_loss: 0.3371 - val_accuracy: 0.9093
# Epoch 90/150
# 134/133 [==============================] - ETA: 0s - loss: 0.3201 - accuracy: 0.8991
# Epoch 90: val_loss did not improve from 0.32012
# 133/133 [==============================] - 17s 125ms/step - loss: 0.3201 - accuracy: 0.8991 - val_loss: 0.3227 - val_accuracy: 0.9178
# Epoch 91/150
# 134/133 [==============================] - ETA: 0s - loss: 0.3109 - accuracy: 0.9063
# Epoch 91: val_loss did not improve from 0.32012
# 133/133 [==============================] - 17s 129ms/step - loss: 0.3109 - accuracy: 0.9063 - val_loss: 0.3394 - val_accuracy: 0.9019
# Epoch 92/150
# 134/133 [==============================] - ETA: 0s - loss: 0.3061 - accuracy: 0.9114
# Epoch 92: val_loss improved from 0.32012 to 0.31168, saving model to ./best_model.h5
# 133/133 [==============================] - 18s 132ms/step - loss: 0.3061 - accuracy: 0.9114 - val_loss: 0.3117 - val_accuracy: 0.9121
# Epoch 93/150
# 134/133 [==============================] - ETA: 0s - loss: 0.3097 - accuracy: 0.9023
# Epoch 93: val_loss did not improve from 0.31168
# 133/133 [==============================] - 17s 127ms/step - loss: 0.3097 - accuracy: 0.9023 - val_loss: 0.3234 - val_accuracy: 0.9028
# Epoch 94/150
# 134/133 [==============================] - ETA: 0s - loss: 0.3135 - accuracy: 0.9072
# Epoch 94: val_loss did not improve from 0.31168
# 133/133 [==============================] - 17s 126ms/step - loss: 0.3135 - accuracy: 0.9072 - val_loss: 0.3415 - val_accuracy: 0.9103
# Epoch 95/150
# 134/133 [==============================] - ETA: 0s - loss: 0.2936 - accuracy: 0.9126
# Epoch 95: val_loss did not improve from 0.31168
# 133/133 [==============================] - 17s 126ms/step - loss: 0.2936 - accuracy: 0.9126 - val_loss: 0.3384 - val_accuracy: 0.9075
# Epoch 96/150
# 134/133 [==============================] - ETA: 0s - loss: 0.3163 - accuracy: 0.9035
# Epoch 96: val_loss did not improve from 0.31168
# 133/133 [==============================] - 17s 126ms/step - loss: 0.3163 - accuracy: 0.9035 - val_loss: 0.3547 - val_accuracy: 0.8897
# Epoch 97/150
# 134/133 [==============================] - ETA: 0s - loss: 0.3019 - accuracy: 0.9042
# Epoch 97: val_loss did not improve from 0.31168
# 133/133 [==============================] - 18s 137ms/step - loss: 0.3019 - accuracy: 0.9042 - val_loss: 0.3285 - val_accuracy: 0.9037
# Epoch 98/150
# 134/133 [==============================] - ETA: 0s - loss: 0.3055 - accuracy: 0.9089
# Epoch 98: val_loss did not improve from 0.31168
# 133/133 [==============================] - 18s 135ms/step - loss: 0.3055 - accuracy: 0.9089 - val_loss: 0.3277 - val_accuracy: 0.9056
# Epoch 99/150
# 134/133 [==============================] - ETA: 0s - loss: 0.3089 - accuracy: 0.9040
# Epoch 99: val_loss did not improve from 0.31168
# 133/133 [==============================] - 18s 131ms/step - loss: 0.3089 - accuracy: 0.9040 - val_loss: 0.3238 - val_accuracy: 0.9159
# Epoch 100/150
# 134/133 [==============================] - ETA: 0s - loss: 0.2910 - accuracy: 0.9136
# Epoch 100: val_loss did not improve from 0.31168
# 133/133 [==============================] - 17s 130ms/step - loss: 0.2910 - accuracy: 0.9136 - val_loss: 0.3196 - val_accuracy: 0.9150
# Epoch 101/150
# 134/133 [==============================] - ETA: 0s - loss: 0.3004 - accuracy: 0.9089
# Epoch 101: val_loss did not improve from 0.31168
# 133/133 [==============================] - 17s 130ms/step - loss: 0.3004 - accuracy: 0.9089 - val_loss: 0.3169 - val_accuracy: 0.9093
# Epoch 102/150
# 134/133 [==============================] - ETA: 0s - loss: 0.3000 - accuracy: 0.9068
# Epoch 102: val_loss did not improve from 0.31168
# 133/133 [==============================] - 17s 130ms/step - loss: 0.3000 - accuracy: 0.9068 - val_loss: 0.3118 - val_accuracy: 0.9187
# Epoch 103/150
# 134/133 [==============================] - ETA: 0s - loss: 0.2841 - accuracy: 0.9124
# Epoch 103: val_loss did not improve from 0.31168
# 133/133 [==============================] - 17s 131ms/step - loss: 0.2841 - accuracy: 0.9124 - val_loss: 0.3221 - val_accuracy: 0.9168
# Epoch 104/150
# 134/133 [==============================] - ETA: 0s - loss: 0.2923 - accuracy: 0.9086
# Epoch 104: val_loss did not improve from 0.31168
# 133/133 [==============================] - 17s 130ms/step - loss: 0.2923 - accuracy: 0.9086 - val_loss: 0.3224 - val_accuracy: 0.9159
# Epoch 105/150
# 134/133 [==============================] - ETA: 0s - loss: 0.3037 - accuracy: 0.9051
# Epoch 105: val_loss did not improve from 0.31168
# 133/133 [==============================] - 18s 131ms/step - loss: 0.3037 - accuracy: 0.9051 - val_loss: 0.3499 - val_accuracy: 0.8944
# Epoch 106/150
# 134/133 [==============================] - ETA: 0s - loss: 0.2725 - accuracy: 0.9112
# Epoch 106: val_loss did not improve from 0.31168
# 133/133 [==============================] - 18s 131ms/step - loss: 0.2725 - accuracy: 0.9112 - val_loss: 0.3285 - val_accuracy: 0.9065
# Epoch 107/150
# 134/133 [==============================] - ETA: 0s - loss: 0.2990 - accuracy: 0.9054
# Epoch 107: val_loss did not improve from 0.31168
# 133/133 [==============================] - 17s 130ms/step - loss: 0.2990 - accuracy: 0.9054 - val_loss: 0.3161 - val_accuracy: 0.9187
# Epoch 108/150
# 134/133 [==============================] - ETA: 0s - loss: 0.2988 - accuracy: 0.9075
# Epoch 108: val_loss did not improve from 0.31168
# 133/133 [==============================] - 17s 131ms/step - loss: 0.2988 - accuracy: 0.9075 - val_loss: 0.3589 - val_accuracy: 0.9178
# Epoch 109/150
# 134/133 [==============================] - ETA: 0s - loss: 0.3022 - accuracy: 0.9058
# Epoch 109: val_loss did not improve from 0.31168
# 133/133 [==============================] - 17s 130ms/step - loss: 0.3022 - accuracy: 0.9058 - val_loss: 0.3380 - val_accuracy: 0.9065
# Epoch 110/150
# 134/133 [==============================] - ETA: 0s - loss: 0.2925 - accuracy: 0.9114
# Epoch 110: val_loss did not improve from 0.31168
# 133/133 [==============================] - 18s 132ms/step - loss: 0.2925 - accuracy: 0.9114 - val_loss: 0.3245 - val_accuracy: 0.9131
# Epoch 111/150
# 134/133 [==============================] - ETA: 0s - loss: 0.2765 - accuracy: 0.9140
# Epoch 111: val_loss did not improve from 0.31168
# 133/133 [==============================] - 17s 131ms/step - loss: 0.2765 - accuracy: 0.9140 - val_loss: 0.3129 - val_accuracy: 0.9150
# Epoch 112/150
# 134/133 [==============================] - ETA: 0s - loss: 0.2972 - accuracy: 0.9047
# Epoch 112: val_loss did not improve from 0.31168
# 133/133 [==============================] - 18s 132ms/step - loss: 0.2972 - accuracy: 0.9047 - val_loss: 0.3327 - val_accuracy: 0.9019
# Epoch 113/150
# 134/133 [==============================] - ETA: 0s - loss: 0.2840 - accuracy: 0.9117
# Epoch 113: val_loss did not improve from 0.31168
# 133/133 [==============================] - 17s 130ms/step - loss: 0.2840 - accuracy: 0.9117 - val_loss: 0.3246 - val_accuracy: 0.9150
# Epoch 114/150
# 134/133 [==============================] - ETA: 0s - loss: 0.2849 - accuracy: 0.9126
# Epoch 114: val_loss did not improve from 0.31168
# 133/133 [==============================] - 18s 131ms/step - loss: 0.2849 - accuracy: 0.9126 - val_loss: 0.3166 - val_accuracy: 0.9206
# Epoch 115/150
# 134/133 [==============================] - ETA: 0s - loss: 0.2879 - accuracy: 0.9107
# Epoch 115: val_loss did not improve from 0.31168
# 133/133 [==============================] - 18s 131ms/step - loss: 0.2879 - accuracy: 0.9107 - val_loss: 0.3203 - val_accuracy: 0.9187
# Epoch 116/150
# 134/133 [==============================] - ETA: 0s - loss: 0.2855 - accuracy: 0.9086
# Epoch 116: val_loss did not improve from 0.31168
# 133/133 [==============================] - 17s 131ms/step - loss: 0.2855 - accuracy: 0.9086 - val_loss: 0.3257 - val_accuracy: 0.9112
# Epoch 117/150
# 134/133 [==============================] - ETA: 0s - loss: 0.2845 - accuracy: 0.9096
# Epoch 117: val_loss did not improve from 0.31168
# 133/133 [==============================] - 17s 130ms/step - loss: 0.2845 - accuracy: 0.9096 - val_loss: 0.3189 - val_accuracy: 0.9187
# Epoch 118/150
# 134/133 [==============================] - ETA: 0s - loss: 0.2814 - accuracy: 0.9145
# Epoch 118: val_loss did not improve from 0.31168
# 133/133 [==============================] - 18s 131ms/step - loss: 0.2814 - accuracy: 0.9145 - val_loss: 0.3245 - val_accuracy: 0.9215
# Epoch 119/150
# 134/133 [==============================] - ETA: 0s - loss: 0.2779 - accuracy: 0.9131
# Epoch 119: val_loss did not improve from 0.31168
# 133/133 [==============================] - 18s 131ms/step - loss: 0.2779 - accuracy: 0.9131 - val_loss: 0.3302 - val_accuracy: 0.9140
# Epoch 120/150
# 134/133 [==============================] - ETA: 0s - loss: 0.2906 - accuracy: 0.9098
# Epoch 120: val_loss did not improve from 0.31168
# 133/133 [==============================] - 17s 130ms/step - loss: 0.2906 - accuracy: 0.9098 - val_loss: 0.3503 - val_accuracy: 0.9028
# Epoch 121/150
# 134/133 [==============================] - ETA: 0s - loss: 0.2824 - accuracy: 0.9129
# Epoch 121: val_loss did not improve from 0.31168
# 133/133 [==============================] - 17s 131ms/step - loss: 0.2824 - accuracy: 0.9129 - val_loss: 0.3712 - val_accuracy: 0.8981
# Epoch 122/150
# 134/133 [==============================] - ETA: 0s - loss: 0.2961 - accuracy: 0.9077
# Epoch 122: val_loss did not improve from 0.31168
# 133/133 [==============================] - 18s 131ms/step - loss: 0.2961 - accuracy: 0.9077 - val_loss: 0.3282 - val_accuracy: 0.9065
# Epoch 123/150
# 134/133 [==============================] - ETA: 0s - loss: 0.2708 - accuracy: 0.9124
# Epoch 123: val_loss did not improve from 0.31168
# 133/133 [==============================] - 18s 131ms/step - loss: 0.2708 - accuracy: 0.9124 - val_loss: 0.3216 - val_accuracy: 0.9093
# Epoch 124/150
# 134/133 [==============================] - ETA: 0s - loss: 0.2795 - accuracy: 0.9126
# Epoch 124: val_loss did not improve from 0.31168
# 133/133 [==============================] - 18s 132ms/step - loss: 0.2795 - accuracy: 0.9126 - val_loss: 0.3199 - val_accuracy: 0.9150
# Epoch 125/150
# 134/133 [==============================] - ETA: 0s - loss: 0.2824 - accuracy: 0.9093
# Epoch 125: val_loss did not improve from 0.31168
# 133/133 [==============================] - 17s 130ms/step - loss: 0.2824 - accuracy: 0.9093 - val_loss: 0.3502 - val_accuracy: 0.9047
# Epoch 126/150
# 134/133 [==============================] - ETA: 0s - loss: 0.2767 - accuracy: 0.9079
# Epoch 126: val_loss did not improve from 0.31168
# 133/133 [==============================] - 18s 132ms/step - loss: 0.2767 - accuracy: 0.9079 - val_loss: 0.3253 - val_accuracy: 0.9112
# Epoch 127/150
# 134/133 [==============================] - ETA: 0s - loss: 0.2757 - accuracy: 0.9164
# Epoch 127: val_loss did not improve from 0.31168
# 133/133 [==============================] - 18s 132ms/step - loss: 0.2757 - accuracy: 0.9164 - val_loss: 0.3158 - val_accuracy: 0.9140
# Epoch 128/150
# 134/133 [==============================] - ETA: 0s - loss: 0.2729 - accuracy: 0.9114
# Epoch 128: val_loss improved from 0.31168 to 0.30470, saving model to ./best_model.h5
# 133/133 [==============================] - 18s 131ms/step - loss: 0.2729 - accuracy: 0.9114 - val_loss: 0.3047 - val_accuracy: 0.9140
# Epoch 129/150
# 134/133 [==============================] - ETA: 0s - loss: 0.2782 - accuracy: 0.9133
# Epoch 129: val_loss did not improve from 0.30470
# 133/133 [==============================] - 18s 132ms/step - loss: 0.2782 - accuracy: 0.9133 - val_loss: 0.3556 - val_accuracy: 0.8991
# Epoch 130/150
# 134/133 [==============================] - ETA: 0s - loss: 0.2705 - accuracy: 0.9093
# Epoch 130: val_loss did not improve from 0.30470
# 133/133 [==============================] - 18s 132ms/step - loss: 0.2705 - accuracy: 0.9093 - val_loss: 0.3158 - val_accuracy: 0.9196
# Epoch 131/150
# 134/133 [==============================] - ETA: 0s - loss: 0.2792 - accuracy: 0.9136
# Epoch 131: val_loss did not improve from 0.30470
# 133/133 [==============================] - 18s 132ms/step - loss: 0.2792 - accuracy: 0.9136 - val_loss: 0.3202 - val_accuracy: 0.9140
# Epoch 132/150
# 134/133 [==============================] - ETA: 0s - loss: 0.2853 - accuracy: 0.9082
# Epoch 132: val_loss did not improve from 0.30470
# 133/133 [==============================] - 18s 131ms/step - loss: 0.2853 - accuracy: 0.9082 - val_loss: 0.3430 - val_accuracy: 0.9047
# Epoch 133/150
# 134/133 [==============================] - ETA: 0s - loss: 0.2834 - accuracy: 0.9126
# Epoch 133: val_loss did not improve from 0.30470
# 133/133 [==============================] - 18s 131ms/step - loss: 0.2834 - accuracy: 0.9126 - val_loss: 0.3444 - val_accuracy: 0.9028
# Epoch 134/150
# 134/133 [==============================] - ETA: 0s - loss: 0.2846 - accuracy: 0.9119
# Epoch 134: val_loss did not improve from 0.30470
# 133/133 [==============================] - 18s 132ms/step - loss: 0.2846 - accuracy: 0.9119 - val_loss: 0.3146 - val_accuracy: 0.9159
# Epoch 135/150
# 134/133 [==============================] - ETA: 0s - loss: 0.2695 - accuracy: 0.9147
# Epoch 135: val_loss did not improve from 0.30470
# 133/133 [==============================] - 18s 132ms/step - loss: 0.2695 - accuracy: 0.9147 - val_loss: 0.3271 - val_accuracy: 0.9112
# Epoch 136/150
# 134/133 [==============================] - ETA: 0s - loss: 0.2745 - accuracy: 0.9164
# Epoch 136: val_loss did not improve from 0.30470
# 133/133 [==============================] - 18s 132ms/step - loss: 0.2745 - accuracy: 0.9164 - val_loss: 0.3318 - val_accuracy: 0.9168
# Epoch 137/150
# 134/133 [==============================] - ETA: 0s - loss: 0.2666 - accuracy: 0.9166
# Epoch 137: val_loss did not improve from 0.30470
# 133/133 [==============================] - 18s 133ms/step - loss: 0.2666 - accuracy: 0.9166 - val_loss: 0.3237 - val_accuracy: 0.9159
# Epoch 138/150
# 134/133 [==============================] - ETA: 0s - loss: 0.2565 - accuracy: 0.9154
# Epoch 138: val_loss did not improve from 0.30470
# 133/133 [==============================] - 18s 132ms/step - loss: 0.2565 - accuracy: 0.9154 - val_loss: 0.3208 - val_accuracy: 0.9159
# Epoch 139/150
# 134/133 [==============================] - ETA: 0s - loss: 0.2724 - accuracy: 0.9161
# Epoch 139: val_loss did not improve from 0.30470
# 133/133 [==============================] - 18s 133ms/step - loss: 0.2724 - accuracy: 0.9161 - val_loss: 0.3327 - val_accuracy: 0.9224
# Epoch 140/150
# 134/133 [==============================] - ETA: 0s - loss: 0.2627 - accuracy: 0.9143
# Epoch 140: val_loss did not improve from 0.30470
# 133/133 [==============================] - 18s 134ms/step - loss: 0.2627 - accuracy: 0.9143 - val_loss: 0.3216 - val_accuracy: 0.9065
# Epoch 141/150
# 134/133 [==============================] - ETA: 0s - loss: 0.2504 - accuracy: 0.9194
# Epoch 141: val_loss did not improve from 0.30470
# 133/133 [==============================] - 18s 132ms/step - loss: 0.2504 - accuracy: 0.9194 - val_loss: 0.3199 - val_accuracy: 0.9140
# Epoch 142/150
# 134/133 [==============================] - ETA: 0s - loss: 0.2577 - accuracy: 0.9154
# Epoch 142: val_loss did not improve from 0.30470
# 133/133 [==============================] - 18s 135ms/step - loss: 0.2577 - accuracy: 0.9154 - val_loss: 0.3090 - val_accuracy: 0.9178
# Epoch 143/150
# 134/133 [==============================] - ETA: 0s - loss: 0.2754 - accuracy: 0.9154
# Epoch 143: val_loss did not improve from 0.30470
# 133/133 [==============================] - 19s 140ms/step - loss: 0.2754 - accuracy: 0.9154 - val_loss: 0.3188 - val_accuracy: 0.9075
# Epoch 144/150
# 134/133 [==============================] - ETA: 0s - loss: 0.2679 - accuracy: 0.9164
# Epoch 144: val_loss improved from 0.30470 to 0.30021, saving model to ./best_model.h5
# 133/133 [==============================] - 19s 139ms/step - loss: 0.2679 - accuracy: 0.9164 - val_loss: 0.3002 - val_accuracy: 0.9187
# Epoch 145/150
# 134/133 [==============================] - ETA: 0s - loss: 0.2482 - accuracy: 0.9164
# Epoch 145: val_loss did not improve from 0.30021
# 133/133 [==============================] - 18s 131ms/step - loss: 0.2482 - accuracy: 0.9164 - val_loss: 0.3365 - val_accuracy: 0.9121
# Epoch 146/150
# 134/133 [==============================] - ETA: 0s - loss: 0.2691 - accuracy: 0.9136
# Epoch 146: val_loss did not improve from 0.30021
# 133/133 [==============================] - 18s 133ms/step - loss: 0.2691 - accuracy: 0.9136 - val_loss: 0.3114 - val_accuracy: 0.9178
# Epoch 147/150
# 134/133 [==============================] - ETA: 0s - loss: 0.2517 - accuracy: 0.9220
# Epoch 147: val_loss did not improve from 0.30021
# 133/133 [==============================] - 18s 132ms/step - loss: 0.2517 - accuracy: 0.9220 - val_loss: 0.3229 - val_accuracy: 0.9196
# Epoch 148/150
# 134/133 [==============================] - ETA: 0s - loss: 0.2609 - accuracy: 0.9157
# Epoch 148: val_loss did not improve from 0.30021
# 133/133 [==============================] - 17s 126ms/step - loss: 0.2609 - accuracy: 0.9157 - val_loss: 0.3172 - val_accuracy: 0.9150
# Epoch 149/150
# 134/133 [==============================] - ETA: 0s - loss: 0.2810 - accuracy: 0.9117
# Epoch 149: val_loss did not improve from 0.30021
# 133/133 [==============================] - 18s 133ms/step - loss: 0.2810 - accuracy: 0.9117 - val_loss: 0.3073 - val_accuracy: 0.9206
# Epoch 150/150
# 134/133 [==============================] - ETA: 0s - loss: 0.2682 - accuracy: 0.9154
# Epoch 150: val_loss did not improve from 0.30021
# 133/133 [==============================] - 18s 133ms/step - loss: 0.2682 - accuracy: 0.9154 - val_loss: 0.3176 - val_accuracy: 0.9178

# %%
model.summary
# Out:
# <bound method Model.summary of <keras.engine.sequential.Sequential object at 0x7f99a06ccbe0>>

# %% [markdown]
# ### Checking the Accuracy of the Model
# Plotting training loss/accuracy vs validation loss/accuracy over the number of epochs. The larger the generalization gap between training and validation curve, the higher the overfitting.
#
# A plot of learning curves shows a good fit if:
# The plot of training loss decreases to a point of stability.
# The plot of validation loss decreases to a point of stability and has a small gap with the training loss.

# %%
plt.figure(figsize = (20,10))
plt.subplot(2,1,1)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel('Epochs')
plt.ylabel('Losses')
plt.legend(['train loss','val loss'])
plt.title('Loss function wrt epochs')

plt.subplot(2,1,2)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['train acc' , 'val acc'])
plt.title('Model accuracy wrt Epoch')
# Out:
# Text(0.5, 1.0, 'Model accuracy wrt Epoch')

# %% [markdown]
# ### Making Predictions

# %%
# loading the model
model = load_model('./best_model.h5')

# %%
# making predictions on test set
y_pred = model.predict(X_test)
# Out:
# 34/34 [==============================] - 1s 28ms/step

# %%
# performing numpy argmax to obtain the value which has the highest probability of being the truth value
y_pred = np.argmax(y_pred, axis = 1)
y_test = np.argmax(y_test, axis = 1)

# %%
target_name = ['2',
 '3',
 '4',
 '5',
 '6',
 '7',
 '8',
 'b',
 'c',
 'd',
 'e',
 'f',
 'g',
 'm',
 'n',
 'p',
 'w',
 'x',
 'y']

# %%
# printing the accuracy & classification report
print('Accuracy: ' + str(accuracy_score(y_test, y_pred)))
print(classification_report(y_test, y_pred, target_names = target_name))
# Out:
# Accuracy: 0.9214953271028037
#               precision    recall  f1-score   support
#
#            2       0.94      0.92      0.93        53
#            3       0.95      0.96      0.95        55
#            4       0.95      0.97      0.96        62
#            5       0.95      0.93      0.94        45
#            6       0.97      1.00      0.98        60
#            7       0.96      0.96      0.96        52
#            8       1.00      0.94      0.97        49
#            b       0.96      0.98      0.97        54
#            c       0.84      0.90      0.87        51
#            d       0.91      0.87      0.89        60
#            e       0.93      0.88      0.91        49
#            f       0.98      0.95      0.97        61
#            g       0.98      0.96      0.97        56
#            m       0.88      0.51      0.65        59
#            n       0.76      0.97      0.85       115
#            p       0.92      0.96      0.94        50
#            w       0.93      0.90      0.92        42
#            x       0.98      0.98      0.98        41
#            y       1.00      0.95      0.97        56
#
#     accuracy                           0.92      1070
#    macro avg       0.94      0.92      0.93      1070
# weighted avg       0.93      0.92      0.92      1070

# %% [markdown]
# ### Testing on Samples

# %%
def test_img(img_path):
    
    img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
    
    plt.imshow(img, 'gray')
    plt.axis('off')
    plt.show()
    
    img = at_img(img)
    img = dil_img(img)
    
    image_list = [img[10:50, 30:50], img[10:50, 50:70], img[10:50, 70:90], img[10:50, 90:110], img[10:50, 110:130]]
    
    Xdemo = []
    for i in range(5) :
        Xdemo.append(img_to_array(Image.fromarray(image_list[i])))
    
    Xdemo = np.array(Xdemo)
    Xdemo/= 255.0
    
    ydemo = model.predict(Xdemo)
    ydemo = np.argmax(ydemo, axis = 1)

    output ='\0'
    for res in ydemo:
        output+= str(info[res])
    print(output)

# %%
test_img('/Users/tthakur/Downloads/Datasets/2g783.png')
test_img('/Users/tthakur/Downloads/Datasets/2fxgd.png')
test_img('/Users/tthakur/Downloads/Datasets/88bgx.png')
test_img('/Users/tthakur/Downloads/Datasets/4yc85.png')
# Out:
# 1/1 [==============================] - 0s 22ms/step
# 2g783
# /opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/data/ops/structured_function.py:264: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   warnings.warn(
# 1/1 [==============================] - 0s 23ms/step
# 2fxgd
# 1/1 [==============================] - 0s 21ms/step
# 88bgx
# 1/1 [==============================] - 0s 26ms/step
# 4yc85
